# %% [markdown]
# ### Problem Statement: The Value-Based Node Expansion Tree
# Consider an infinite, rooted tree where the vertices are labeled sequentially with positive integers starting from 1 at the root.
#
# The structure of the tree is uniquely determined by a single rule: every node i has exactly i children. The children of any node are assigned consecutive, strictly increasing integer labels based on the order of their birth (breadth-first order).
#
# The tree's first few levels develop as follows:
# 1. Level 1: Contains the root node 1. It has 1 child.
# 2. Level 2: Contains node 2 (the child of 1). It has 2 children.
# 3. Level 3: Contains nodes 3 and 4 (the children of 2). Node 3 spawns 3 children, and Node 4 spawns 4 children.
# 4. Level 4: Contains nodes 5, 6, 7 (children of 3) and nodes 8, 9, 10, 11 (children of 4).
#
# Given an input integer K (K>1), determine the label of its parent node.

# %%
def func(processNumber):
    i = 1
    l = 0
    h = 0
    pl = 0
    ph = 0
    s = 1
    # d = 0
    while(True):
        l = i + 1
        h = i + 1 + s 
        if (processNumber >= l) and (processNumber < h):
            # d = d + 1
            break
        s = sum(range(l,h))
        pl = l
        ph = h
        i = h - 1
        # d = d + 1
    # print(f"l:{l}, h:{h}")
    # print(f"pl:{pl}, ph:{ph}")
    # print(f"depth:{d}")
    f = ph
    for i in range(pl,ph):
        if (processNumber >=f) and (processNumber < f+i):
            return i
        f = f + i
    
        

print(func(10))

# %% [markdown]
# Question 1 (Python Coding)
#
# You are given:
#
# * RES: an array of length N, where RES[i] represents the number of issues already resolved for machine i.
# * REQ: an array of length N, where REQ[i] represents the minimum number of resolved issues required for machine i to be considered maintainable.
# * An integer K, representing the total number of additional issues that can be resolved and distributed among the N machines in any manner.
#
# A machine is considered maintainable if:
#
# RES[i] \ge REQ[i]
#
# You may distribute the K additional issue resolutions across the machines in any way. Determine the maximum number of maintainable machines that can be obtained after optimally allocating the K additional issue resolutions.
#
# Function Inputs
#
# * RES: List of integers
# * REQ: List of integers
# * K: Integer
#
# Output
#
# * Return an integer representing the maximum number of maintainable machines that can be achieved.
#
# Solution:
# 1. in a for loop add the difference between the res and req if res < req to a list else increase the count for maintainable machines by 1 if res>=req:
# 2. sort the list in ascending
# 3. sum the values in list and increase the count value by one for each
# 4. return count
